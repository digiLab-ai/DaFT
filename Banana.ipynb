# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from daft import DaFT

# %%
np.random.seed(123)

# %%
def get_banana(X, a=2, b=0.5):
    X[:,0], X[:,1] = a*X[:,0], X[:,1]/a + b*(X[:,0]**2 + a**2)
    return X

# %%
n_samples = 10000
n_sub = 20

n_dim = 2
n_features = 2000

# %%
P = get_banana(np.random.normal(loc=0, scale=1, size=(n_samples, n_dim)))

# %%
Q_random = P[np.random.randint(P.shape[0], size=n_sub), :]

# %%
my_daft = DaFT(P, n_sub, n_features)
Q_best = my_daft.run(n=500, ngen=200)

# %%
plt.figure(figsize=(6,4))
plt.scatter(P[:,0], P[:,1], alpha=0.1, c='k')
plt.scatter(Q_random[:,0], Q_random[:,1], alpha=1, c='tomato')
plt.scatter(Q_best[:,0], Q_best[:,1], alpha=1, c='springgreen')
plt.show()
